# %%
#import the modules
import os
import pandas as pd
#read the path
file_path = "/Users/sarrabenyahia/Documents/GitHub/sentimental-analysis-energy-stocks/data/temp"
#list all the files from the directory
file_list = os.listdir(file_path)
file_list
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 3
#       1 #import the modules
#       2 import os
# ----> 3 import pandas as pd
#       4 #read the path
#       5 file_path = "/Users/sarrabenyahia/Documents/GitHub/sentimental-analysis-energy-stocks/data/temp"
#
# ModuleNotFoundError: No module named 'pandas'

# %%
#import modules
import os
import glob
import pandas as pd
#list all csv files only
csv_files = glob.glob('*.{}'.format('csv'))
csv_files
# Out:
# ['webscraped_BP_PLC22.csv',
#  'webscraped_BP_PLC36.csv',
#  'webscraped_BP_PLC6.csv',
#  'webscraped_BP_PLC7.csv',
#  'webscraped_BP_PLC37.csv',
#  'webscraped_BP_PLC23.csv',
#  'webscraped_BP_PLC35.csv',
#  'webscraped_BP_PLC21.csv',
#  'webscraped_BP_PLC5.csv',
#  'webscraped_BP_PLC4.csv',
#  'webscraped_BP_PLC20.csv',
#  'webscraped_BP_PLC34.csv',
#  'webscraped_BP_PLC30.csv',
#  'webscraped_BP_PLC24.csv',
#  'webscraped_BP_PLC18.csv',
#  'webscraped_BP_PLC1.csv',
#  'webscraped_BP_PLC19.csv',
#  'webscraped_BP_PLC25.csv',
#  'webscraped_BP_PLC31.csv',
#  'webscraped_BP_PLC27.csv',
#  'webscraped_BP_PLC33.csv',
#  'webscraped_BP_PLC3.csv',
#  'webscraped_BP_PLC2.csv',
#  'webscraped_BP_PLC32.csv',
#  'webscraped_BP_PLC26.csv',
#  'webscraped_BP_PLC41.csv',
#  'webscraped_BP_PLC40.csv',
#  'webscraped_BP_PLC42.csv',
#  'webscraped_BP_PLC43.csv',
#  'webscraped_BP_PLC47.csv',
#  'webscraped_BP_PLC46.csv',
#  'webscraped_BP_PLC44.csv',
#  'webscraped_BP_PLC45.csv',
# ...

# %%
df_append = pd.DataFrame()
#append all files together
for file in csv_files:
            df_temp = pd.read_csv(file)
            df_append = df_append.append(df_temp, ignore_index=True)
df_append
# Out:
# /var/folders/4l/60lgrf9s6sqbf6lcr70gbl2c0000gn/T/ipykernel_60313/3254637134.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_append = df_append.append(df_temp, ignore_index=True)
# /var/folders/4l/60lgrf9s6sqbf6lcr70gbl2c0000gn/T/ipykernel_60313/3254637134.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_append = df_append.append(df_temp, ignore_index=True)
# /var/folders/4l/60lgrf9s6sqbf6lcr70gbl2c0000gn/T/ipykernel_60313/3254637134.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_append = df_append.append(df_temp, ignore_index=True)
# ...

# %%
df_append.sort_values("PostDate", ascending=False, inplace=True)

# %%
df_append.to_csv("/Users/sarrabenyahia/Documents/GitHub/overperforming-58-energy-stocks/data/webscraped_BP_PLC.csv", index=False)
